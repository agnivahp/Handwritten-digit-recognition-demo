# %% [markdown]
# # Handwritten Digit Recognition - Deep Neural Networks
# ## Notebook by <a href="https://github.com/agnivahp"><u>Agnivah Poddar</u></a>
# ### University of Illinois - Urbana Champaign
# ---

# %% [markdown]
# ## Table of Contents
# 1. <a href='#Intro'>Introduction</a>
# 2. <a href='#License'>License</a>
# 3. <a href='#Req'>Required Libraries</a>
# 4. Problem domain
# 5. <a href='#step1'>Step 1 - Answering the question</a>
# 6. <a href='#step2'>Step 2 - A simple 1-layer neural network</a>
# 7. <a href='#step3'>Step 3 - Improving the network</a>
# 8. Step 4
# 9. Conclusions
# 10. References
# 11. Acknowledgements
#
# ---

# %% [markdown]
# <a id='Intro'></a>
# ## Introduction
# In this notebook, we will progressively build and improve a neural network that recognizes hand-written digits all the way to 99% accuracy.
#
# As we build and train the network, we will discover the tools that are used to model deep neural networks efficiently and learn about some tricks that can be used to improve the performance.
# We will be using the famous MNIST dataset which consists of 60,000 labeled handwritten digits. We will start with a simple one layer network and add more layers to go on to build a more complex 5 layered convolutional network.
#
# ---

# %% [markdown]
# <a id='License'></a>
# ## License
#
# ---

# %% [markdown]
# <a id='Req'></a>
# ## Required Libraries
# We will need the following for this demo:
# - Python3
# - Tensorflow
# - Matplotlib
#
# You can install the latest version of python 3 from https://www.python.org/downloads/
#
# If you are a MacOS user like me, you can use the following commands:
# ```bash
#  pip3 install --upgrade tensorflow
#  pip3 install --upgrade matplotlib
# ```
# If you wish to use some other specific environment, visit tensorflow.org and follow the Python 3 instructions.
#
# ---

# %% [markdown]
# ## Problem Domain
# Our aim is to create a demo machine learning model that trains itself based off the MNIST digits and is able to recognize any handwritten digit given to it with maximum accuracy.
#
# Our dataset looks like this:
#
# ![dataset](https://kuanhoong.files.wordpress.com/2016/01/mnistdigits.gif "Digits from the dataset")
#
#
# We have the digits along with their correct labels which will be used for training the network. We also have another set of digits that the network has not seen before. Our network should be able to correctly recognize and classify these new digits.
#
# ---

# %% [markdown]
# <a id='step1'></a>
# ## Step 1 - Answering the question
#
# The first step is to understand the problem we are trying to solve, analyzing the given data and then defining a measure for our success at solving that problem.
#
# In this demo we are trying to recognize handwritten digits that have never been seen before and correctly classify them.
#
# Since it is a classification problem, the accuracy of our model in correctly labeling digits should be a good measure for determining the performance of our network.
#
# ---

# %% [markdown]
# <a id='step2'></a>
# ## Step 2 - A simple 1-layer neural network
#
# The digits in the MNIST dataset are 28x28 pixels greyscale images. The simplest approach would be to have these 28x28 = 784 pixels to be our input for our one layer network.
#
# ![oneLayer](https://codelabs.developers.google.com/codelabs/cloud-tensorflow-mnist/img/d5222c6e3d15770a.png "1-layer network")
#
# A <b>neuron</b> in a neural network takes in the inputs and performs a weighted sum and adds some bias to it. The sum is then passed through some <b>activation function </b>.
#
# In this case, we are classifying digits into 10 classes (0 to 9). Hence, our 1-layer network needs 10 output neurons. The activation function that we will be using is called <b>softmax</b>.
#
# ![softmax](https://codelabs.developers.google.com/codelabs/cloud-tensorflow-mnist/img/604a9797da2a48d7.png "Softmax activation function")
#
# What this function does is that it will exponentially increase the differences between the elements of the vector and after normalising it, the largest value will be close to 1 and every other element will be close to 0. This way we clearly see which digit it has classified it as, and at the same time the relative ordering of values is also maintained.
#
# Once we have the predictions, we need to check how accurate those were. This can be determined by checking the results of the network against what the provided correct labels tell us. We use a distance called <b>cross-entropy</b>. This efficiently computes the distance between the predicted and correct answer.
#
# ![cross-entropy](entropy.png "Softmax activation function")
#
# Our aim is to train the model by trying to minimize this distance by altering our weights and biases slightly. This is basically what the training process involves.
#
# The partial derivative of cross entropy relative to the weights and biases, gives us the <b>gradient</b> which tells us which direction to go in order to reduce the loss. Thus in each iteration of thr training step, we modify our weights and biases slightly, in order to reach the local minima of the cross-entropy. An important thing to note here is that our <b>learning rate</b> which is the step size at which we alter the weights and biases needs to be small. We cannot be taking large steps as then we may cross the minimum and enter an infinte loop of back and forth.
#
# ![gradient descent](https://media.licdn.com/mpr/mpr/AAEAAQAAAAAAAAesAAAAJGU5ZDhlYzk2LTgzZjMtNDllNC1iNWQwLTE0MDY3MDkxODBlZA.png "Gradient descent")
#
#
# ### Let us now code this simple network:
#
# First let's import the packages that we would need and read the dataset.

# %%
#tensorflow demo Digit recognition
# %matplotlib inline

import tensorflow as tf
import tensorflowvisu
import math
from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets
tf.set_random_seed(0)

#logging is used to log our intermediate progress in a separtate file
import logging
logging.basicConfig(filename='intermediate.log',level=logging.DEBUG)

# Download images and labels into mnist.test (10K images+labels) and mnist.train (60K images+labels)
mnist = read_data_sets("data", one_hot=True, reshape=False, validation_size=0)
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# We then define all the variables and placeholders that we will need.
# Variables are the parameters that the training algorithm will determine. Placeholders are the parameters that are inputted during training.

# %%
#placeholder for training set
X = tf.placeholder(tf.float32, [None, 28, 28, 1])

#variables to be determined
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))

# %% [markdown]
# We then create our model. The activation function that we use is <b>softmax</b>. We need another placeholder that holds the correct labels of the digits in the training set.
#
# We use tensorflow's <a href="https://www.tensorflow.org/api_docs/python/tf/train/GradientDescentOptimizer">GradientDescent</a> as our optimizer to minimize the cross-entropy.

# %%
#model
Y = tf.nn.softmax(tf.matmul(tf.reshape(X,[-1, 784]), W) + b)
#placeholder for correct labels
Y_ = tf.placeholder(tf.float32, [None, 10])

#loss function that needs to be minimized
cross_entropy = -tf.reduce_mean(Y_ * tf.log(Y))*1000.0

#optimizer
optimizer = tf.train.GradientDescentOptimizer(0.003)
train_step = optimizer.minimize(cross_entropy)

# % of correct answers found in batch
is_correct = tf.equal(tf.argmax(Y,1), tf.argmax(Y_,1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

# matplotlib visualisation
allweights = tf.reshape(W, [-1])
allbiases = tf.reshape(b, [-1])
I = tensorflowvisu.tf_format_mnist_images(X, Y, Y_)  # assembles 10x10 images by default
It = tensorflowvisu.tf_format_mnist_images(X, Y, Y_, 1000, lines=25)  # 1000 images on 25 lines
datavis = tensorflowvisu.MnistDataVis()

# %% [markdown]
# It is now time to train our network. This is done by writing a function <b>training_step</b> that loops and trains in batches of 100 images at a time.

# %%
#training
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)


# You can call this function in a loop to train the model, 100 images at a time
def training_step(i, update_test_data, update_train_data):

    # training on batches of 100 images with 100 labels
    batch_X, batch_Y = mnist.train.next_batch(100)

    # compute training values for visualisation
    if update_train_data:
        a, c, im, w, b = sess.run([accuracy, cross_entropy, I, allweights, allbiases], feed_dict={X: batch_X, Y_: batch_Y})
        datavis.append_training_curves_data(i, a, c)
        datavis.append_data_histograms(i, w, b)
        datavis.update_image1(im)
        logging.debug(str(i) + ": accuracy:" + str(a) + " loss: " + str(c))
        #logging.info('So should this')
        #print(str(i) + ": accuracy:" + str(a) + " loss: " + str(c))

    # compute test values for visualisation
    if update_test_data:
        a, c, im = sess.run([accuracy, cross_entropy, It], feed_dict={X: mnist.test.images, Y_: mnist.test.labels})
        datavis.append_test_curves_data(i, a, c)
        datavis.update_image2(im)
        logging.debug(str(i) + ": ********* epoch " + str(i*100//mnist.train.images.shape[0]+1) +
                      " ********* test accuracy:" + str(a) + " test loss: " + str(c))
        #print(str(i) + ": ********* epoch " + 
        #str(i*100//mnist.train.images.shape[0]+1) + " ********* test accuracy:" + str(a) + " test loss: " + str(c))

    # the backpropagation training step
    sess.run(train_step, feed_dict={X: batch_X, Y_: batch_Y})

#animation
datavis.animate(training_step, iterations=10000+1, train_data_update_freq=10, test_data_update_freq=50, more_tests_at_start=True)

print("Test accuracy: " + str(float(str(datavis.get_max_test_accuracy()))*100) + '%')
#str(datavis.get_max_test_accuracy()))
# Out:
# Test accuracy: 92.69%

# %% [markdown]
# <a id='step3'></a>
# # Step 3 - Improving the network
# With our very simple 1-layer network we were able to achieve an accuracy of >92%. While this may seem to be high, when applying this model to real world applications, it is a very poor performance. We need to find ways of improving our model to give a better performance.
#
# ### Adding more layers
# We can improve our network by adding more layers. The neurons in the subsequent layers compute the weighted sums of neuron outputs from the previous layer.
#
# To add more layers, we will need additional weights and biases for all the intermediate layers.

# %%
# five layers and their number of neurons (tha last layer has 10 softmax neurons)
L1 = 200
L2 = 100
L3 = 60
L4 = 30

# Weights initialised with small random values between -0.2 and +0.2
W1 = tf.Variable(tf.truncated_normal([784, L1], stddev=0.1))  # 784 = 28 * 28
B1 = tf.Variable(tf.ones([L1])/10)
W2 = tf.Variable(tf.truncated_normal([L1, L2], stddev=0.1))
B2 = tf.Variable(tf.ones([L2])/10)
W3 = tf.Variable(tf.truncated_normal([L3, L4], stddev=0.1))
B3 = tf.Variable(tf.ones([L4])/10)
W4 = tf.Variable(tf.truncated_normal([L4, L5], stddev=0.1))
B4 = tf.Variable(tf.ones([L5])/10)
W5 = tf.Variable(tf.truncated_normal([L5, 10], stddev=0.1))
B5 = tf.Variable(tf.zeros([10]))

# %% [markdown]
# ### Use a better classification function
#
# We will continue to use the softmax function as our activation function, but will use a new function called <b>relu</b> for the intermediate layers:
#
# ![relu](https://ml4a.github.io/images/figures/relu.png "Relu")
#
# We now change our model to a 5-layer model:

# %%
# The model
XX = tf.reshape(X, [-1, 784])
Y1 = tf.nn.relu(tf.matmul(XX, W1) + B1)
Y2 = tf.nn.relu(tf.matmul(Y1, W2) + B2)
Y3 = tf.nn.relu(tf.matmul(Y2, W3) + B3)
Y4 = tf.nn.relu(tf.matmul(Y3, W4) + B4)
Y = tf.nn.softmax(tf.matmul(Y4, W5) + B5)

# %% [markdown]
# ### Time to train our model again.
#
# ##### NOTE: If the accuracy curve crashes, it means that we are trying to compute log(0). To avoid this, we can use tensorflows's function to compute our cross-entropy in a numerically stable way. We will need to isolate the raw weigted sum before softmax is applied on the last layer.
#
# Replace last line of model which was :
# ```python
#     Y = tf.nn.softmax(tf.matmul(Y4, W5) + B5)
# ```
# with,
#
# ```python
#     Ylogits = tf.matmul(Y4, W5) + B5
#     Y = tf.nn.softmax(Ylogits)
# ```
#
# Now we can safely calculate the cross-entropy as:

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(Ylogits, Y_)

# to apply same scale to test and training cross-entropy for display
cross_entropy = tf.reduce_mean(cross_entropy)*100
# Out:
# max test accuracy: 0.9823

# %% [markdown]
# We see that just by adding more layers and using better functions, we were able to improve the accuracy to >98%.
#
# However, when we observe the cross-entropy plot we notice that the loss seems to be increasing as we do more iterations. The model learns well for the training data but after a while its not able to perform so well on new never seen before test data and so the cross-entropy loss starts shooting up again.
#
#
# This is known as <a href="https://en.wikipedia.org/wiki/Overfitting"><b>OVERFITTING</b></a>. A model can overfit due to multiple reasons - not enough data, complex model with too many parameters, etc.
#
# In our case, we have too many neurons. One technique that we can use to prevent overfitting is called <b>Dropout</b>.
#
# ### Dropout
# In this technique we drop random neurons during each iteration. We choose a probalitity for a neuron to be kept and then at each iteration randomly remove neurons.
#
# ![dropout](http://everglory99.github.io/Intro_DL_TCC/intro_dl_images/dropout1.png "Dropout")
#
# At the time of testing our network though, we put back all the neurons.
#
# This can achieved using the <a href="https://www.tensorflow.org/versions/r1.1/api_docs/python/tf/nn/dropout">*dropout*</a> function that tensorflow provides. This function will randomly zero-out outputs of some neurons and boost other neurons in proportion.

# %% [markdown]
# We now need to modify our model with a dropout at each level

# %%
XX = tf.reshape(X, [-1, 28*28])

Y1 = tf.nn.relu(tf.matmul(XX, W1) + B1)
Y1d = tf.nn.dropout(Y1, pkeep)

Y2 = tf.nn.relu(tf.matmul(Y1d, W2) + B2)
Y2d = tf.nn.dropout(Y2, pkeep)

Y3 = tf.nn.relu(tf.matmul(Y2d, W3) + B3)
Y3d = tf.nn.dropout(Y3, pkeep)

Y4 = tf.nn.relu(tf.matmul(Y3d, W4) + B4)
Y4d = tf.nn.dropout(Y4, pkeep)

Ylogits = tf.matmul(Y4d, W5) + B5
Y = tf.nn.softmax(Ylogits)
# Out:
# Test accuracy: 0.9821

# %% [markdown]
# After training the above model with dropout, we see that our accuracy is not affected much but the cross-entropy loss is brought back in control and is no longer shooting up. This means that our model now has a better predictive power.
#
# ---

# %% [markdown]
# <a id='step4'></a>
# # Step 4 - Convolutional networks

# %%
#tensorflow demo Digit recognition
#CNN

import math

#placeholder for training set
X = tf.placeholder(tf.float32, [None, 28, 28, 1])

#learning rate exponentially decaying
learningRate = tf.placeholder(tf.float32)

#variables to be determined
# w = tf.Variable(tf.zeros([784,10]))
# b = tf.Variable(tf.zeros([10]))
W1 = tf.Variable(tf.truncated_normal([5, 5, 1, 4], stddev=0.1))
B1 = tf.Variable(tf.ones([4])/10) # 2 is the number of output channels

W2 = tf.Variable(tf.truncated_normal([5, 5, 4, 8], stddev=0.1))
B2 = tf.Variable(tf.ones([8])/10) # 2 is the number of output channels

W3 = tf.Variable(tf.truncated_normal([4, 4, 8, 12], stddev=0.1))
B3 = tf.Variable(tf.ones([12])/10) # 2 is the number of output channels

W4 = tf.Variable(tf.truncated_normal([7*7*12, 200], stddev=0.1))
B4 = tf.Variable(tf.ones([200])/10) # 2 is the number of output channels

W5 = tf.Variable(tf.truncated_normal([200, 10], stddev=0.1))
B5 = tf.Variable(tf.ones([10])/10) # 2 is the number of output channels



# Y = tf.nn.softmax(tf.matmul(tf.reshape(X,[-1, 784]), w) + b)
#XX = tf.reshape(X, [-1, 28*28])

#dropout to take care of overfitting
pkeep = tf.placeholder(tf.float32)

#model
stride = 1  # output is still 28x28
Y1cnv = tf.nn.conv2d(X, W1, strides=[1, stride, stride, 1], padding='SAME')
Y1 = tf.nn.relu(Y1cnv + B1)
#Y1d = tf.nn.dropout(Y1, pkeep)
stride = 2
Y2cnv = tf.nn.conv2d(Y1, W2, strides=[1, stride, stride, 1], padding='SAME')
Y2 = tf.nn.relu(Y2cnv + B2)
#Y2d = tf.nn.dropout(Y2, pkeep)
stride = 2
Y3cnv = tf.nn.conv2d(Y2, W3, strides=[1, stride, stride, 1], padding='SAME')
Y3 = tf.nn.relu(Y3cnv + B3)
#Y3d = tf.nn.dropout(Y3, pkeep)

YY = tf.reshape(Y3, shape=[-1, 7*7*12])
Y4 = tf.nn.relu(tf.matmul(YY,W4) + B4)
Y4d = tf.nn.dropout(Y4, pkeep)

Ylogits = tf.matmul(Y4d, W5) + B5
Y = tf.nn.softmax(Ylogits)
#Y5cnv = tf.nn.conv2d(Y4d, W5, strides=[1, stride, stride, 1], padding='SAME')
#Y5 = tf.nn.relu(Y5cnv + B5)
#Y5d = tf.nn.dropout(Y5, pkeep)



#placeholder for correct labels
Y_ = tf.placeholder(tf.float32, [None, 10])

#loss function that needs to be minimized

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=Ylogits, labels=Y_)
cross_entropy = tf.reduce_mean(cross_entropy)*100

# % of correct answers found in batch
is_correct = tf.equal(tf.argmax(Y,1), tf.argmax(Y_,1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

#optimizer
optimizer = tf.train.AdamOptimizer(learningRate)
train_step = optimizer.minimize(cross_entropy)


# matplotlib visualisation
allweights = tf.concat([tf.reshape(W1, [-1]), tf.reshape(W2, [-1])], 0)
allbiases  = tf.concat([tf.reshape(B1, [-1]), tf.reshape(B2, [-1])], 0)
I = tensorflowvisu.tf_format_mnist_images(X, Y, Y_)  # assembles 10x10 images by default
It = tensorflowvisu.tf_format_mnist_images(X, Y, Y_, 1000, lines=25)  # 1000 images on 25 lines
datavis = tensorflowvisu.MnistDataVis()


#training
lrmin = 0.0001
lrmax = 0.003
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)


#Training the model, 100 images at a time
def training_step(i, update_test_data, update_train_data):

    # training on batches of 100 images with 100 labels
    batch_X, batch_Y = mnist.train.next_batch(100)
    lr = lrmin+(lrmax-lrmin)*math.exp(-i/2000)
    # compute training values for visualisation
    if update_train_data:
        a, c, im, w, b = sess.run([accuracy, cross_entropy, I, allweights, allbiases], feed_dict={X: batch_X, Y_: batch_Y, learningRate: lr, pkeep: 0.75})
        datavis.append_training_curves_data(i, a, c)
        datavis.append_data_histograms(i, w, b)
        datavis.update_image1(im)
        logging.debug(str(i) + ": accuracy:" + str(a) + " loss: " + str(c))
        #print(str(i) + ": accuracy:" + str(a) + " loss: " + str(c))

    # compute test values for visualisation
    if update_test_data:
        a, c, im = sess.run([accuracy, cross_entropy, It], feed_dict={X: mnist.test.images, Y_: mnist.test.labels, pkeep: 1})
        datavis.append_test_curves_data(i, a, c)
        datavis.update_image2(im)
        logging.debug(str(i) + ": ********* epoch " + 
                      str(i*100//mnist.train.images.shape[0]+1) + " ********* test accuracy:" + 
                      str(a) + " test loss: " + str(c))
        #print(str(i) + ": ********* epoch " + str(i*100//mnist.train.images.shape[0]+1) + " ********* test accuracy:" + str(a) + " test loss: " + str(c))

    # the backpropagation training step
    sess.run(train_step, feed_dict={X: batch_X, Y_: batch_Y, learningRate: lr, pkeep: 0.75})


#to animate plots
datavis.animate(training_step, iterations=10000+1, train_data_update_freq=10, test_data_update_freq=50, more_tests_at_start=True)

#for i in range(10000+1):
 #   training_step(i, i % 50 == 0, i % 10 == 0)

print("Test accuracy: " + str(datavis.get_max_test_accuracy()))
# Out:
# Test accuracy: 0.9915

# %% [markdown]
# ## Conclusion
#
# ---

# %% [markdown]
# ## Acknowledgements
#
# ---
